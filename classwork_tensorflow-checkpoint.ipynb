# %%
pip install tensorflow
# Out:
# ...
#    ---------------------------------------- 0.0/332.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/332.0 MB 12.9 MB/s eta 0:00:26
#    ---------------------------------------- 3.4/332.0 MB 11.1 MB/s eta 0:00:30
#     --------------------------------------- 5.2/332.0 MB 9.7 MB/s eta 0:00:34
#     --------------------------------------- 7.6/332.0 MB 10.1 MB/s eta 0:00:33
#    - -------------------------------------- 9.7/332.0 MB 10.0 MB/s eta 0:00:33
#    - -------------------------------------- 11.3/332.0 MB 10.0 MB/s eta 0:00:33
#    - -------------------------------------- 14.2/332.0 MB 10.1 MB/s eta 0:00:32
#    - -------------------------------------- 16.5/332.0 MB 10.3 MB/s eta 0:00:31
#    -- ------------------------------------- 18.9/332.0 MB 10.3 MB/s eta 0:00:31
#    -- ------------------------------------- 21.5/332.0 MB 10.5 MB/s eta 0:00:30
#    -- ------------------------------------- 23.6/332.0 MB 10.5 MB/s eta 0:00:30
#
# ...

# %%
import tensorflow as tf
from tensorflow import keras

# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
test = pd.read_csv('A:/1 - DS phyton/учебные датасеты/test.csv')
train = pd.read_csv('A:/1 - DS phyton/учебные датасеты/train.csv')

# %%
train
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
test
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
# ...

# %%
heatdf  = train

plt.figure(figsize=(16,10), dpi= 80)
sns.heatmap(heatdf.corr(), xticklabels=heatdf.corr().columns, yticklabels=heatdf.corr().columns, cmap='RdYlGn', center=0, annot=True)

plt.title('price', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
x2 = train[['battery_power', 'px_height', 'px_width', 'ram']]

# %%
x2
# Out:
#       battery_power  px_height  px_width   ram
# 0               842         20       756  2549
# 1              1021        905      1988  2631
# 2               563       1263      1716  2603
# 3               615       1216      1786  2769
# 4              1821       1208      1212  1411
# ...             ...        ...       ...   ...
# 1995            794       1222      1890   668
# 1996           1965        915      1965  2032
# 1997           1911        868      1632  3057
# 1998           1512        336       670   869
# 1999            510        483       754  3919
#
# [2000 rows x 4 columns]

# %%
print(train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
train.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
x = train.drop('price_range', axis=1) 
y = train['price_range']

# %%
# Создаем модель
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(20, )),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(4)
])
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Компилируем модель
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.fit(x, y, epochs=20)
# Out:
# Epoch 1/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.4050 - loss: 37.4716
# Epoch 2/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5155 - loss: 6.5130
# Epoch 3/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5215 - loss: 5.0213
# Epoch 4/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5800 - loss: 3.0904
# Epoch 5/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5950 - loss: 3.3723
# Epoch 6/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6005 - loss: 3.5447
# Epoch 7/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6210 - loss: 2.5854
# Epoch 8/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6290 - loss: 2.4218
# Epoch 9/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6295 - loss: 2.7008
# Epoch 10/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6285 - loss: 2.7418
# Epoch 11/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6145 - loss: 3.8759
# Epoch 12/20
# ...

# %%
# Оценим то2чность модели
x, y = model.evaluate(x,  y, verbose=2)
print('\nТестовая точность:', y)
# Out:
# 63/63 - 0s - 7ms/step - accuracy: 0.7280 - loss: 1.3699
#
# Тестовая точность: 0.7279999852180481

# %%
x2 = train[['battery_power', 'px_height', 'px_width', 'ram']]  
y = train['price_range']

# %%
# сокращенный X
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(4, )),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(4)
])
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Компилируем модель
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.fit(x2, y, epochs=30)
# Out:
# Epoch 1/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4070 - loss: 54.3184
# Epoch 2/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4760 - loss: 10.7689
# Epoch 3/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4855 - loss: 6.7182
# Epoch 4/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5015 - loss: 6.3457
# Epoch 5/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4950 - loss: 4.8601
# Epoch 6/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4775 - loss: 6.2977
# Epoch 7/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4895 - loss: 4.7499
# Epoch 8/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4875 - loss: 5.8839
# Epoch 9/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5095 - loss: 4.3285
# Epoch 10/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5105 - loss: 4.9945
# Epoch 11/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5075 - loss: 4.0065
# Epoch 12/30
# ...

# %%
# Оценим точность модели
x2, y = model.evaluate(x2,  y, verbose=2)
print('\nТестовая точность:', y)
# Out:
# 63/63 - 0s - 7ms/step - accuracy: 0.5895 - loss: 2.1627
#
# Тестовая точность: 0.5895000100135803
