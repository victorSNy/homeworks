# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('A:/1 - DS phyton/учебные датасеты/ParisHousing.csv')

# %%
df.head()
# Out:
#    squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0         75523              3        0        1      63      9373
# 1         80771             39        1        1      98     39381
# 2         55712             58        0        1      19     34457
# 3         32316             47        0        0       6     27939
# 4         70429             19        1        1      90     38045
#
#    cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# 0              3              8  2005           0                  1
# 1              8              6  2015           1                  0
# 2              6              8  2021           0                  0
# 3             10              4  2012           0                  1
# 4              3              7  1990           1                  0
#
#    basement  attic  garage  hasStorageRoom  hasGuestRoom      price
# 0      4313   9005     956               0             7  7559081.5
# ...

# %%
df.dtypes
# Out:
# squareMeters           int64
# numberOfRooms          int64
# hasYard                int64
# hasPool                int64
# floors                 int64
# cityCode               int64
# cityPartRange          int64
# numPrevOwners          int64
# made                   int64
# isNewBuilt             int64
# hasStormProtector      int64
# basement               int64
# attic                  int64
# garage                 int64
# hasStorageRoom         int64
# hasGuestRoom           int64
# price                float64
# dtype: object

# %%
df.describe()
# Out:
#        squareMeters  numberOfRooms       hasYard       hasPool        floors  \
# count   10000.00000   10000.000000  10000.000000  10000.000000  10000.000000
# mean    49870.13120      50.358400      0.508700      0.496800     50.276300
# std     28774.37535      28.816696      0.499949      0.500015     28.889171
# min        89.00000       1.000000      0.000000      0.000000      1.000000
# 25%     25098.50000      25.000000      0.000000      0.000000     25.000000
# 50%     50105.50000      50.000000      1.000000      0.000000     50.000000
# 75%     74609.75000      75.000000      1.000000      1.000000     76.000000
# max     99999.00000     100.000000      1.000000      1.000000    100.000000
#
#            cityCode  cityPartRange  numPrevOwners         made    isNewBuilt  \
# count  10000.000000   10000.000000   10000.000000  10000.00000  10000.000000
# mean   50225.486100       5.510100       5.521700   2005.48850      0.499100
# ...

# %%
plt.figure(figsize=(16,14), dpi= 80)
sns.heatmap(df.corr(), xticklabels=df.corr().columns, yticklabels=df.corr().columns, cmap='RdYlGn', center=0, annot=True)

plt.title('price', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
plt.plot(df['price'], df['squareMeters'])
plt.xlabel('цена')
plt.ylabel('метр квадратный')
plt.show()

# %%
sns.histplot(data=df, x="price")
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
y = df['price']
x = df.drop(columns = ['price'])

# %%
y
# Out:
# 0       7559081.5
# 1       8085989.5
# 2       5574642.1
# 3       3232561.2
# 4       7055052.0
#           ...
# 9995     176425.9
# 9996    4448474.0
# 9997    8390030.5
# 9998    5905107.0
# 9999     146708.4
# Name: price, Length: 10000, dtype: float64

# %%
x
# Out:
#       squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0            75523              3        0        1      63      9373
# 1            80771             39        1        1      98     39381
# 2            55712             58        0        1      19     34457
# 3            32316             47        0        0       6     27939
# 4            70429             19        1        1      90     38045
# ...            ...            ...      ...      ...     ...       ...
# 9995          1726             89        0        1       5     73133
# 9996         44403             29        1        1      12     34606
# 9997         83841              3        0        0      69     80933
# 9998         59036             70        0        0      96     55856
# 9999          1440             84        0        0      49     18412
#
#       cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42)

# %%
reg = LinearRegression().fit(x, y)

# %%
reg.predict(x_test)
# Out:
# array([7962676.17157593, 3715905.56187681, 8553857.3255413 , ...,
#        1951254.35807354, 2945502.61509471, 7042669.24786975])

# %%
y_test
# Out:
# 6252    7964369.6
# 4684    3713548.9
# 1731    8553019.2
# 4742    6428666.2
# 4521    6465184.9
#           ...
# 6412    6951279.2
# 8285    8152737.7
# 7853    1947709.8
# 1095    2944295.3
# 6929    7041725.7
# Name: price, Length: 2000, dtype: float64

# %%
reg.coef_
# Out:
# array([ 1.00000024e+02,  2.51844810e-01,  3.01229551e+03,  2.97713775e+03,
#         5.45420542e+01, -8.03888243e-04,  4.73685001e+01, -3.95730186e-01,
#        -2.31311931e+00,  1.58041540e+02,  1.41196130e+02, -2.10562533e-03,
#        -4.50939065e-03,  1.13432814e-01,  1.94856126e+01, -5.62033751e+00])

# %%
reg.intercept_
# Out:
# np.float64(4926.758592897095)

# %%
from sklearn.metrics import mean_absolute_error

# %%
y_pred = reg.predict(x_test)

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 1506.8369581803736

# %%
mean_absolute_error(y_test, y_pred, multioutput='raw_values')
# Out:
# array([1506.83695818])

# %%
from sklearn.metrics import mean_squared_error

# %%
e = mean_squared_error(y_test, y_pred)

# %%
print(e**0.5)
# Out:
# 1918.8034571634446

# %%
plt.plot(df['price'], df['numberOfRooms'])
plt.xlabel('цена')
plt.ylabel('количество комнат')
plt.show()

# %%
plt.plot(df['price'], df['garage'])
plt.xlabel('цена')
plt.ylabel('гараж')
plt.show()

# %%
means_price = df['price'].mean()

plt.figure(figsize=(12, 6))
sns.barplot(data=df, x='garage', y=means_price)
plt.xticks(rotation=45)
plt.ylabel('Среднее значение')
plt.tight_layout()
plt.show()
