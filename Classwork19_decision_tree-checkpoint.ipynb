# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import tensorflow as tf
import keras

# %%
df1 = pd.read_csv('C:\Victor\Credit_card.csv')

# %%
df2 = pd.read_csv('C:\Victor\Credit_card_label.csv')

# %%
df1
# Out:
#        Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0     5008827      M         Y             Y         0       180000.0
# 1     5009744      F         Y             N         0       315000.0
# 2     5009746      F         Y             N         0       315000.0
# 3     5009749      F         Y             N         0            NaN
# 4     5009752      F         Y             N         0       315000.0
# ...       ...    ...       ...           ...       ...            ...
# 1543  5028645      F         N             Y         0            NaN
# 1544  5023655      F         N             N         0       225000.0
# 1545  5115992      M         Y             Y         2       180000.0
# 1546  5118219      M         Y             N         0       270000.0
# 1547  5053790      F         Y             Y         0       225000.0
#
#                Type_Income                      EDUCATION  \
# 0                Pensioner               Higher education
# ...

# %%
df2
# Out:
#        Ind_ID  label
# 0     5008827      1
# 1     5009744      1
# 2     5009746      1
# 3     5009749      1
# 4     5009752      1
# ...       ...    ...
# 1543  5028645      0
# 1544  5023655      0
# 1545  5115992      0
# 1546  5118219      0
# 1547  5053790      0
#
# [1548 rows x 2 columns]

# %%
df1.describe
# Out:
# <bound method NDFrame.describe of        Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0     5008827      M         Y             Y         0       180000.0
# 1     5009744      F         Y             N         0       315000.0
# 2     5009746      F         Y             N         0       315000.0
# 3     5009749      F         Y             N         0            NaN
# 4     5009752      F         Y             N         0       315000.0
# ...       ...    ...       ...           ...       ...            ...
# 1543  5028645      F         N             Y         0            NaN
# 1544  5023655      F         N             N         0       225000.0
# 1545  5115992      M         Y             Y         2       180000.0
# 1546  5118219      M         Y             N         0       270000.0
# 1547  5053790      F         Y             Y         0       225000.0
#
#                Type_Income                      EDUCATION  \
# ...

# %%
df1.dtypes
# Out:
# Ind_ID               int64
# GENDER              object
# Car_Owner           object
# Propert_Owner       object
# CHILDREN             int64
# Annual_income      float64
# Type_Income         object
# EDUCATION           object
# Marital_status      object
# Housing_type        object
# Birthday_count     float64
# Employed_days        int64
# Mobile_phone         int64
# Work_Phone           int64
# Phone                int64
# EMAIL_ID             int64
# Type_Occupation     object
# Family_Members       int64
# dtype: object

# %%
df1.isna().sum()
# Out:
# Ind_ID               0
# GENDER               7
# Car_Owner            0
# Propert_Owner        0
# CHILDREN             0
# Annual_income       23
# Type_Income          0
# EDUCATION            0
# Marital_status       0
# Housing_type         0
# Birthday_count      22
# Employed_days        0
# Mobile_phone         0
# Work_Phone           0
# Phone                0
# EMAIL_ID             0
# Type_Occupation    488
# Family_Members       0
# dtype: int64

# %%
df3=df1.fillna(0)

# %%
df3.isna().sum()
# Out:
# Ind_ID             0
# GENDER             0
# Car_Owner          0
# Propert_Owner      0
# CHILDREN           0
# Annual_income      0
# Type_Income        0
# EDUCATION          0
# Marital_status     0
# Housing_type       0
# Birthday_count     0
# Employed_days      0
# Mobile_phone       0
# Work_Phone         0
# Phone              0
# EMAIL_ID           0
# Type_Occupation    0
# Family_Members     0
# dtype: int64

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

# %%
df3['GENDER'] = df3['GENDER'].map({'M': 1, 'F': 2, 0: 0}).astype(int)

# %%
df3['Car_Owner'] = df3['Car_Owner'].map({'Y': 1, 'N': 0}).astype(int)

# %%
df3['Propert_Owner'] = df3['Propert_Owner'].map({'Y': 1, 'N': 0}).astype(int)

# %%
df3['Type_Income'].value_counts()
# Out:
# Type_Income
# Working                 798
# Commercial associate    365
# Pensioner               269
# State servant           116
# Name: count, dtype: int64

# %%
df3['Type_Income'] = df3['Type_Income'].map({'Pensioner': 1, 'Commercial associate': 2, 'Working': 3, 'State servant': 4}).astype(int)

# %%
df3['EDUCATION'].value_counts()
# Out:
# EDUCATION
# Secondary / secondary special    1031
# Higher education                  426
# Incomplete higher                  68
# Lower secondary                    21
# Academic degree                     2
# Name: count, dtype: int64

# %%
df3['EDUCATION'] = df3['EDUCATION'].map({'Secondary / secondary special': 1, 'Higher education': 2, 'Incomplete higher': 3, 'Lower secondary': 4, 'Academic degree': 5  }).astype(int)

# %%
plt.figure(figsize=(16,10), dpi= 80)
sns.heatmap(df3.corr(), xticklabels=df3.corr().columns, yticklabels=df3.corr().columns, cmap='RdYlGn', center=0, annot=True)

plt.title('price', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[101], line 2
#       1 plt.figure(figsize=(16,10), dpi= 80)
# ----> 2 sns.heatmap(df3.corr(), xticklabels=df3.corr().columns, yticklabels=df3.corr().columns, cmap='RdYlGn', center=0, annot=True)
#       4 plt.title('price', fontsize=22)
#       5 plt.xticks(fontsize=12)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# ...

# %%
df3['Marital_status'].value_counts()

# %%
df3['Housing_type'].value_counts()
# Out:
# Housing_type
# House / apartment      1380
# With parents             80
# Municipal apartment      53
# Rented apartment         21
# Office apartment          9
# Co-op apartment           5
# Name: count, dtype: int64

# %%
df3.dtypes
# Out:
# Ind_ID               int64
# GENDER               int64
# Car_Owner            int64
# Propert_Owner        int64
# CHILDREN             int64
# Annual_income      float64
# Type_Income          int64
# EDUCATION            int64
# Marital_status      object
# Housing_type        object
# Birthday_count     float64
# Employed_days        int64
# Mobile_phone         int64
# Work_Phone           int64
# Phone                int64
# EMAIL_ID             int64
# Type_Occupation     object
# Family_Members       int64
# dtype: object

# %%
df3['Housing_type'] = df3['Housing_type'].map({'House / apartment': 1, 'With parents': 2, 'Municipal apartment': 3, 'Rented apartment': 4, 'Office apartment': 5, 'Co-op apartment': 6 }).astype(int)

# %%
df3['Type_Occupation'].value_counts()
# Out:
# Type_Occupation
# 0                        488
# Laborers                 268
# Core staff               174
# Managers                 136
# Sales staff              122
# Drivers                   86
# High skill tech staff     65
# Medicine staff            50
# Accountants               44
# Security staff            25
# Cleaning staff            22
# Cooking staff             21
# Private service staff     17
# Low-skill Laborers         9
# Secretaries                9
# Waiters/barmen staff       5
# HR staff                   3
# IT staff                   2
# Realty agents              2
# Name: count, dtype: int64

# %%
df3= df3.drop(columns=["Type_Occupation"])

# %%
df3
# Out:
#        Ind_ID  GENDER  Car_Owner  Propert_Owner  CHILDREN  Annual_income  \
# 0     5008827       1          1              1         0       180000.0
# 1     5009744       2          1              0         0       315000.0
# 2     5009746       2          1              0         0       315000.0
# 3     5009749       2          1              0         0            0.0
# 4     5009752       2          1              0         0       315000.0
# ...       ...     ...        ...            ...       ...            ...
# 1543  5028645       2          0              1         0            0.0
# 1544  5023655       2          0              0         0       225000.0
# 1545  5115992       1          1              1         2       180000.0
# 1546  5118219       1          1              0         0       270000.0
# 1547  5053790       2          1              1         0       225000.0
#
#       Type_Income  EDUCATION        Marital_status  Housing_type  \
# ...

# %%
df_merged = pd.merge(df3, df2, on='Ind_ID', how='inner') 
df_merged
# Out:
#        Ind_ID  GENDER  Car_Owner  Propert_Owner  CHILDREN  Annual_income  \
# 0     5008827       1          1              1         0       180000.0
# 1     5009744       2          1              0         0       315000.0
# 2     5009746       2          1              0         0       315000.0
# 3     5009749       2          1              0         0            0.0
# 4     5009752       2          1              0         0       315000.0
# ...       ...     ...        ...            ...       ...            ...
# 1543  5028645       2          0              1         0            0.0
# 1544  5023655       2          0              0         0       225000.0
# 1545  5115992       1          1              1         2       180000.0
# 1546  5118219       1          1              0         0       270000.0
# 1547  5053790       2          1              1         0       225000.0
#
#       Type_Income  EDUCATION        Marital_status  Housing_type  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
df_merged = df_merged.drop(columns=["Type_Occupation"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[110], line 1
# ----> 1 df_merged = df_merged.drop(columns=["Type_Occupation"])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
# ...

# %%
df_merged['Marital_status'] = df_merged['Marital_status'].map({'Married': 1, 'Single / not married': 2, 'Civil marriage': 3, 'Separated': 4, 'Widow': 5  }).astype(int)

# %%
df_merged['Housing_type'] = df_merged['Housing_type'].map({'House / apartment': 1, 'With parents': 2, 'Municipal apartment': 3, 'Rented apartment': 4, 'Office apartment': 5, 'Co-op apartment': 6 }).astype(int)

# %%
x = df_merged.drop(columns=["label"])
y = df_merged['label']

# %%
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.2, random_state=42)

# %%
df_merged['Marital_status'].value_counts()

# %%
from sklearn.model_selection import cross_val_score
clf = tree.DecisionTreeClassifier(random_state=0, max_depth = 5)
cross_val_score(clf, x_train, y_train, cv=10)
# Out:
# array([0.87096774, 0.87903226, 0.88709677, 0.86290323, 0.87903226,
#        0.87903226, 0.87903226, 0.87903226, 0.91056911, 0.8699187 ])

# %%
clf = clf.fit(x_train, y_train)

# %%
plt.figure(figsize=(20,12))
tree.plot_tree(clf) 
plt.show()

# %%
print(clf.score(x_train, y_train))
print(clf.score(x_test, y_test))
# Out:
# 0.9022617124394184
# 0.8935483870967742

# %%
y_predict = clf.predict(x_test)

# %%
import tensorflow as tf
from tensorflow import keras

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(17, )),
    keras.layers.Dense(126, activation='relu'),
    keras.layers.Dense(2)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.fit(x_test, y_test, epochs=10)
# Out:
# Epoch 1/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.7903 - loss: 45917.1211
# Epoch 2/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8484 - loss: 21769.6504
# Epoch 3/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9032 - loss: 24589.5137
# Epoch 4/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7226 - loss: 9492.1641
# Epoch 5/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9032 - loss: 16564.1895
# Epoch 6/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7806 - loss: 5724.2197
# Epoch 7/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8355 - loss: 3321.0383
# Epoch 8/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8387 - loss: 3766.0444
# Epoch 9/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7968 - loss: 5034.0283
# Epoch 10/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8065 - loss: 4417.2793

# %%
test_loss_2, test_acc_2 = model.evaluate(x_test, y_test, verbose=2)
print('\nТестовая точность:', test_acc_2)
# Out:
# 10/10 - 1s - 51ms/step - accuracy: 0.9032 - loss: 5598.2905
#
# Тестовая точность: 0.9032257795333862

# %%
# Модель 1: Линейная классификация с L1 (Lasso)
log_l1 = LogisticRegression(
    penalty='l1',
    solver='liblinear',
    max_iter=1000
)
log_l1.fit(X_train_clf_scaled, y_train_clf)
y_pred_l1 = log_l1.predict(X_test_clf_scaled)

current_acc = accuracy_score(y_test_clf, y_pred_l1)
acc_scores_list.append(current_acc)
model_names_list.append('Линейная классификация с L1')
print(f"LogReg L1 Accuracy: {current_acc:.4f}")

# %%
from sklearn import svm

# %%
# Модель 4: SVC (линейный)
from sklearn import svm
svc = SVC(kernel='linear', C=1.0)
svc.fit(x_train, y_train)
y_pred_svc = svc.predict(x_test)

current_acc = accuracy_score(y_test, y_preidict)
acc_scores_list.append(current_acc)
model_names_list.append('SVC (линейный)')
print(f"SVC Accuracy: {current_acc:.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[119], line 3
#       1 # Модель 4: SVC (линейный)
#       2 from sklearn import svm
# ----> 3 svc = SVC(kernel='linear', C=1.0)
#       4 svc.fit(x_train, y_train)
#       5 y_pred_svc = svc.predict(x_test)
#
# NameError: name 'SVC' is not defined
